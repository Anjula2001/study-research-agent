# %%
import pandas as pd

data = {
    "Name": ["Anjula", "Anjali", "Tharindu", "Savindi", "Kasun"],
    "Age": [25, 24, 29, 31, 27],
    "Study_Hours": [5, 6, 3, 8, 4],
    "Marks": [75, 82, 55, 92, 68]
}

df = pd.DataFrame(data)

df
# Out:
#        Name  Age  Study_Hours  Marks
# 0    Anjula   25            5     75
# 1    Anjali   24            6     82
# 2  Tharindu   29            3     55
# 3   Savindi   31            8     92
# 4     Kasun   27            4     68

# %%
df.shape
# Out:
# (5, 4)

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Study_Hours', 'Marks'], dtype='str')

# %%
df.dtypes
# Out:
# Name             str
# Age            int64
# Study_Hours    int64
# Marks          int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         5 non-null      str
#  1   Age          5 non-null      int64
#  2   Study_Hours  5 non-null      int64
#  3   Marks        5 non-null      int64
# dtypes: int64(3), str(1)
# memory usage: 292.0 bytes

# %%
df.describe()
# Out:
#              Age  Study_Hours     Marks
# count   5.000000     5.000000   5.00000
# mean   27.200000     5.200000  74.40000
# std     2.863564     1.923538  14.01071
# min    24.000000     3.000000  55.00000
# 25%    25.000000     4.000000  68.00000
# 50%    27.000000     5.000000  75.00000
# 75%    29.000000     6.000000  82.00000
# max    31.000000     8.000000  92.00000

# %%
df.isnull().sum()
# Out:
# Name           0
# Age            0
# Study_Hours    0
# Marks          0
# dtype: int64

# %%
messy_df = df.copy()

messy_df.loc[2, "Age"] = None
messy_df.loc[4, "Marks"] = None

messy_df
# Out:
#        Name   Age  Study_Hours  Marks
# 0    Anjula  25.0            5   75.0
# 1    Anjali  24.0            6   82.0
# 2  Tharindu   NaN            3   55.0
# 3   Savindi  31.0            8   92.0
# 4     Kasun  27.0            4    NaN

# %%
messy_df.isnull().sum()
# Out:
# Name           0
# Age            1
# Study_Hours    0
# Marks          1
# dtype: int64

# %%
messy_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         5 non-null      str
#  1   Age          4 non-null      float64
#  2   Study_Hours  5 non-null      int64
#  3   Marks        4 non-null      float64
# dtypes: float64(2), int64(1), str(1)
# memory usage: 292.0 bytes

# %%
clean_df = messy_df.dropna()

clean_df
# Out:
#       Name   Age  Study_Hours  Marks
# 0   Anjula  25.0            5   75.0
# 1   Anjali  24.0            6   82.0
# 3  Savindi  31.0            8   92.0

# %%
messy_df.loc[2, "Age"] = 26

# %%
messy_df.isnull().sum()
# Out:
# Name           0
# Age            0
# Study_Hours    0
# Marks          1
# dtype: int64

# %%
messy_df.loc[4, "Marks"] = 78.5

# %%
messy_df.isnull().sum()
# Out:
# Name           0
# Age            0
# Study_Hours    0
# Marks          0
# dtype: int64

# %%
duplicate_df = pd.concat([df, df.iloc[[0]]], ignore_index=True)

duplicate_df
# Out:
#        Name  Age  Study_Hours  Marks
# 0    Anjula   25            5     75
# 1    Anjali   24            6     82
# 2  Tharindu   29            3     55
# 3   Savindi   31            8     92
# 4     Kasun   27            4     68
# 5    Anjula   25            5     75

# %%
duplicate_df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# dtype: bool

# %%
clean_duplicate_df = duplicate_df.drop_duplicates()

# %%
clean_duplicate_df
# Out:
#        Name  Age  Study_Hours  Marks
# 0    Anjula   25            5     75
# 1    Anjali   24            6     82
# 2  Tharindu   29            3     55
# 3   Savindi   31            8     92
# 4     Kasun   27            4     68

# %%
clean_duplicate_df.shape
# Out:
# (5, 4)

# %%
df.sort_values(by="Marks")
# Out:
#        Name  Age  Study_Hours  Marks
# 2  Tharindu   29            3     55
# 4     Kasun   27            4     68
# 0    Anjula   25            5     75
# 1    Anjali   24            6     82
# 3   Savindi   31            8     92

# %%
df.sort_values(by="Marks", ascending= False)
# Out:
#        Name  Age  Study_Hours  Marks
# 3   Savindi   31            8     92
# 1    Anjali   24            6     82
# 0    Anjula   25            5     75
# 4     Kasun   27            4     68
# 2  Tharindu   29            3     55

# %%
df["Marks"] >= 70
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# 4    False
# Name: Marks, dtype: bool

# %%
df[df["Marks"] >= 70]
# Out:
#       Name  Age  Study_Hours  Marks
# 0   Anjula   25            5     75
# 1   Anjali   24            6     82
# 3  Savindi   31            8     92

# %%
df[(df["Marks"] >= 70) & (df["Study_Hours"] >= 5)]
# Out:
#       Name  Age  Study_Hours  Marks
# 0   Anjula   25            5     75
# 1   Anjali   24            6     82
# 3  Savindi   31            8     92

# %%
df[(df["Marks"] >= 70) | (df["Study_Hours"] >= 5)]
# Out:
#       Name  Age  Study_Hours  Marks
# 0   Anjula   25            5     75
# 1   Anjali   24            6     82
# 3  Savindi   31            8     92

# %%
df.loc[df["Marks"] >= 70, ["Name", "Marks"]]
# Out:
#       Name  Marks
# 0   Anjula     75
# 1   Anjali     82
# 3  Savindi     92

# %%
df.loc[df["Marks"] >= 70, ["Name", "Marks"]].sort_values(by = "Marks", ascending = False)
# Out:
#       Name  Marks
# 3  Savindi     92
# 1   Anjali     82
# 0   Anjula     75

# %%
df[df["Name"].isin(["Anjula", "Kasun"])]
# Out:
#      Name  Age  Study_Hours  Marks
# 0  Anjula   25            5     75
# 4   Kasun   27            4     68

# %%
df.groupby("Age")["Marks"].mean()
# Out:
# Age
# 24    82.0
# 25    75.0
# 27    68.0
# 29    55.0
# 31    92.0
# Name: Marks, dtype: float64

# %%
df
# Out:
#        Name  Age  Study_Hours  Marks
# 0    Anjula   25            5     75
# 1    Anjali   24            6     82
# 2  Tharindu   29            3     55
# 3   Savindi   31            8     92
# 4     Kasun   27            4     68

# %%
df.groupby("Age")["Marks"].agg(["mean", "max", "min"])
# Out:
#      mean  max  min
# Age
# 24   82.0   82   82
# 25   75.0   75   75
# 27   68.0   68   68
# 29   55.0   55   55
# 31   92.0   92   92

# %%
df.groupby("Age")[["Study_Hours", "Marks"]].mean()
# Out:
#      Study_Hours  Marks
# Age
# 24           6.0   82.0
# 25           5.0   75.0
# 27           4.0   68.0
# 29           3.0   55.0
# 31           8.0   92.0

# %%
df["Age"].value_counts()
# Out:
# Age
# 25    1
# 24    1
# 29    1
# 31    1
# 27    1
# Name: count, dtype: int64

# %%
df.loc[df["Study_Hours"] >= 5, ["Name","Marks"]].max()
# Out:
# Name     Savindi
# Marks         92
# dtype: object

# %%
df
# Out:
#        Name  Age  Study_Hours  Marks
# 0    Anjula   25            5     75
# 1    Anjali   24            6     82
# 2  Tharindu   29            3     55
# 3   Savindi   31            8     92
# 4     Kasun   27            4     68

# %%
df.loc[df["Study_Hours"] >= 5, ["Name", "Study_Hours", "Marks"]].sort_values(by = "Marks", ascending = False).head(1)
# Out:
#       Name  Study_Hours  Marks
# 3  Savindi            8     92

# %%
df["Study_Hours"].corr(df["Marks"])
# Out:
# np.float64(0.9795867790060778)

# %%
df[["Age", "Study_Hours", "Marks"]].corr()
# Out:
#                   Age  Study_Hours     Marks
# Age          1.000000     0.217858  0.047357
# Study_Hours  0.217858     1.000000  0.979587
# Marks        0.047357     0.979587  1.000000

# %%
df["Marks"].quantile(0.25)
# Out:
# np.float64(68.0)

# %%
df["Marks"].quantile(0.75)
# Out:
# np.float64(82.0)

# %%
df["Marks"].quantile(0.5)
# Out:
# np.float64(75.0)

# %%
q1 = df["Marks"].quantile(0.25)
q3 = df["Marks"].quantile(0.75)

iqr = q3 - q1

iqr
# Out:
# np.float64(14.0)

# %%
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr

lower_bound, upper_bound
# Out:
# (np.float64(47.0), np.float64(103.0))

# %%
import matplotlib.pyplot as plt
plt.scatter(df["Study_Hours"], df["Marks"])

plt.xlabel("Study_Hours")
plt.ylabel("Marks")
plt.title("Study Hours vs Marks")

plt.show()

# %%
df.columns = df.columns.str.strip()

# %%
df
# Out:
#        Name  Age  Study_Hours  Marks
# 0    Anjula   25            5     75
# 1    Anjali   24            6     82
# 2  Tharindu   29            3     55
# 3   Savindi   31            8     92
# 4     Kasun   27            4     68

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Study_Hours', 'Marks'], dtype='str')

# %%
df.value_counts()
# Out:
# Name      Age  Study_Hours  Marks
# Anjula    25   5            75       1
# Anjali    24   6            82       1
# Tharindu  29   3            55       1
# Savindi   31   8            92       1
# Kasun     27   4            68       1
# Name: count, dtype: int64

# %%
duplicate_df
# Out:
#        Name  Age  Study_Hours  Marks
# 0    Anjula   25            5     75
# 1    Anjali   24            6     82
# 2  Tharindu   29            3     55
# 3   Savindi   31            8     92
# 4     Kasun   27            4     68
# 5    Anjula   25            5     75

# %%
df["Marks"].value_counts()
# Out:
# Marks
# 75    1
# 82    1
# 55    1
# 92    1
# 68    1
# Name: count, dtype: int64

# %%
df["Name"].value_counts()
# Out:
# Name
# Anjula      1
# Anjali      1
# Tharindu    1
# Savindi     1
# Kasun       1
# Name: count, dtype: int64

# %%
df["Study_Hours"].value_counts()
# Out:
# Study_Hours
# 5    1
# 6    1
# 3    1
# 8    1
# 4    1
# Name: count, dtype: int64

# %%
df["Age"].value_counts()
# Out:
# Age
# 25    1
# 24    1
# 29    1
# 31    1
# 27    1
# Name: count, dtype: int64

# %%
duplicate_df
# Out:
#        Name  Age  Study_Hours  Marks
# 0    Anjula   25            5     75
# 1    Anjali   24            6     82
# 2  Tharindu   29            3     55
# 3   Savindi   31            8     92
# 4     Kasun   27            4     68
# 5    Anjula   25            5     75

# %%
df[df["Study_Hours"] >= 5]
# Out:
#       Name  Age  Study_Hours  Marks
# 0   Anjula   25            5     75
# 1   Anjali   24            6     82
# 3  Savindi   31            8     92

# %%
df[df["Study_Hours"] >= 5].sort_values(by = "Marks" , ascending = False ).head(2)
# Out:
#       Name  Age  Study_Hours  Marks
# 3  Savindi   31            8     92
# 1   Anjali   24            6     82

# %%
df[df["Study_Hours"] >= 5].sort_values(by = "Marks" , ascending = False ).head(2)
# Out:
#       Name  Age  Study_Hours  Marks
# 3  Savindi   31            8     92
# 1   Anjali   24            6     82
