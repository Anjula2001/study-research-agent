# %%
import pandas as pd

data = {
    "Name" : ["Anjula","Anjali","Tharindu","Savindi"],
    "Age" : [25,25,29,31],
    "Marks" : [70,80,90,100]
}
df = pd.DataFrame(data)
print(df)
# Out:
#        Name  Age  Marks
# 0    Anjula   25     70
# 1    Anjali   25     80
# 2  Tharindu   29     90
# 3   Savindi   31    100

# %%
df["Marks"]
# Out:
# 0     70
# 1     80
# 2     90
# 3    100
# Name: Marks, dtype: int64

# %%
df["Age"]
# Out:
# 0    25
# 1    25
# 2    29
# 3    31
# Name: Age, dtype: int64

# %%
df["Marks"]
# Out:
# 0     70
# 1     80
# 2     90
# 3    100
# Name: Marks, dtype: int64

# %%
df["Marks"].mean()
# Out:
# np.float64(85.0)

# %%
df.describe()
# Out:
#         Age       Marks
# count   4.0    4.000000
# mean   27.5   85.000000
# std     3.0   12.909944
# min    25.0   70.000000
# 25%    25.0   77.500000
# 50%    27.0   85.000000
# 75%    29.5   92.500000
# max    31.0  100.000000

# %%
df.isnull().sum()
# Out:
# Name     0
# Age      0
# Marks    0
# dtype: int64

# %%
df["Age"].max()
# Out:
# np.int64(31)
