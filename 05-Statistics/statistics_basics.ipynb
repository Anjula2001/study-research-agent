# %%
import pandas as pd
data = {
    "Name": ["Anjula", "Anjali", "Tharindu", "Savindi", "Kasun"],
    "Age": [25, 24, 29, 31, 27],
    "Study_Hours": [5, 6, 3, 8, 4],
    "Marks": [75, 82, 55, 92, 68]
}

df = pd.DataFrame(data)

df
# Out:
#        Name  Age  Study_Hours  Marks
# 0    Anjula   25            5     75
# 1    Anjali   24            6     82
# 2  Tharindu   29            3     55
# 3   Savindi   31            8     92
# 4     Kasun   27            4     68

# %%
df["Marks"].var()
# Out:
# np.float64(196.3)

# %%
df["Marks"].var(ddof=0)
# Out:
# np.float64(157.04000000000002)

# %%
df["Marks"].std()
# Out:
# np.float64(14.010710188994704)

# %%
z = (75 - df["Marks"].mean()) / df["Marks"].std()
z
# Out:
# np.float64(0.04282438162708478)

# %%
(92 - df["Marks"].mean()) / df["Marks"].std()
# Out:
# np.float64(1.256181861061165)
