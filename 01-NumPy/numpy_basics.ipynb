# %%
print ("Hello world")
# Out:
# Hello world

# %%
name = "Anjula"
age = 25

print (name)
print(age)
# Out:
# Anjula
# 25

# %%
import numpy as np

numbers = np.array([10, 20, 30, 40, 50])

print(numbers)
print(numbers.mean())
# Out:
# [10 20 30 40 50]
# 30.0

# %%
import numpy as np

numbers = np.array([10, 20, 30, 40, 50])

print(numbers)
print("Mean is : " ,numbers.mean())
# Out:
# [10 20 30 40 50]
# Mean is :  30.0
