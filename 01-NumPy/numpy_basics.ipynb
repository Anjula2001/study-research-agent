# %%
Hello World
# Out:
#   Cell In[1], line 1
#     Hello World
#           ^
# SyntaxError: invalid syntax

# %%
print ("Hello world")
# Out:
# Hello world

# %%
name = "Anjula"
age = 25

print (name)
print(age)
# Out:
# Anjula
# 25

# %%
import numpy as np

numbers = np.array([10, 20, 30, 40, 50])

print(numbers)
print(numbers.mean())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import numpy as np
#       2
#       3 numbers = np.array([10, 20, 30, 40, 50])
#       4
#
# ModuleNotFoundError: No module named 'numpy'

# %%
import numpy as np

numbers = np.array([10, 20, 30, 40, 50])

print(numbers)
print(numbers.mean())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import numpy as np
#       2
#       3 numbers = np.array([10, 20, 30, 40, 50])
#       4
#
# ModuleNotFoundError: No module named 'numpy'

# %%
import numpy as np

numbers = np.array([10, 20, 30, 40, 50])

print(numbers)
print(numbers.mean())
# Out:
# [10 20 30 40 50]
# 30.0

# %%
import numpy as np

numbers = np.array([10, 20, 30, 40, 50])

print(numbers)
print("Mean is : " ,numbers.mean())
# Out:
# [10 20 30 40 50]
# Mean is :  30.0

# %%
import pandas as pd

# %%
data = {
# Out:
#   Cell In[8], line 1
#     data = {
#             ^
# _IncompleteInputError: incomplete input

# %%
data = {
    "Name" ["Anjula","Anjali","Tharindu","Savindi"],
    "Age" [25,25,29,31],
    "Marks" [70,80,90,100]
}
# Out:
# <>:2: SyntaxWarning: str indices must be integers or slices, not tuple; perhaps you missed a comma?
# <>:3: SyntaxWarning: str indices must be integers or slices, not tuple; perhaps you missed a comma?
# <>:4: SyntaxWarning: str indices must be integers or slices, not tuple; perhaps you missed a comma?
# /var/folders/rd/nk8dl3y111d2tg7vjm9phvmw0000gn/T/ipykernel_69627/3857932786.py:2: SyntaxWarning: str indices must be integers or slices, not tuple; perhaps you missed a comma?
#   "Name" ["Anjula","Anjali","Tharindu","Savindi"],
# /var/folders/rd/nk8dl3y111d2tg7vjm9phvmw0000gn/T/ipykernel_69627/3857932786.py:3: SyntaxWarning: str indices must be integers or slices, not tuple; perhaps you missed a comma?
#   "Age" [25,25,29,31],
# /var/folders/rd/nk8dl3y111d2tg7vjm9phvmw0000gn/T/ipykernel_69627/3857932786.py:4: SyntaxWarning: str indices must be integers or slices, not tuple; perhaps you missed a comma?
#   "Marks" [70,80,90,100]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 data = {
# ----> 2     "Name" ["Anjula","Anjali","Tharindu","Savindi"],
#       3     "Age" [25,25,29,31],
#       4     "Marks" [70,80,90,100]
#       5 }
#
# TypeError: string indices must be integers, not 'tuple'

# %%
data = {
    "Name" ["Anjula","Anjali","Tharindu","Savindi"],
    "Age" [25,25,29,31],
    "Marks" [70,80,90,100]
}
df = pd.DataFrame(data)
print(df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 data = {
# ----> 2     "Name" ["Anjula","Anjali","Tharindu","Savindi"],
#       3     "Age" [25,25,29,31],
#       4     "Marks" [70,80,90,100]
#       5 }
#
# TypeError: string indices must be integers, not 'tuple'

# %%
import pandas as pd
data = {
    "Name" ["Anjula","Anjali","Tharindu","Savindi"],
    "Age" [25,25,29,31],
    "Marks" [70,80,90,100]
}
df = pd.DataFrame(data)
print(df)
# Out:
# <>:5: SyntaxWarning: str indices must be integers or slices, not tuple; perhaps you missed a comma?
# /var/folders/rd/nk8dl3y111d2tg7vjm9phvmw0000gn/T/ipykernel_69627/731765383.py:5: SyntaxWarning: str indices must be integers or slices, not tuple; perhaps you missed a comma?
#   "Marks" [70,80,90,100]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 3
#       1 import pandas as pd
#       2 data = {
# ----> 3     "Name" ["Anjula","Anjali","Tharindu","Savindi"],
#       4     "Age" [25,25,29,31],
#       5     "Marks" [70,80,90,100]
#       6 }
#
# TypeError: string indices must be integers, not 'tuple'

# %%
import pandas as pd

data = {
    "Name" : ["Anjula","Anjali","Tharindu","Savindi"],
    "Age" : [25,25,29,31],
    "Marks" : [70,80,90,100]
}
df = pd.DataFrame(data)
print(df)
# Out:
#        Name  Age  Marks
# 0    Anjula   25     70
# 1    Anjali   25     80
# 2  Tharindu   29     90
# 3   Savindi   31    100

# %%
df["Marks"]
# Out:
# 0     70
# 1     80
# 2     90
# 3    100
# Name: Marks, dtype: int64

# %%
df["Age"]
# Out:
# 0    25
# 1    25
# 2    29
# 3    31
# Name: Age, dtype: int64

# %%
df["marks"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/INtREC/ML project/.venv/lib/python3.13/site-packages/pandas/core/indexes/base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7676 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: 'marks'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df["marks"]
#
# File ~/INtREC/ML project/.venv/lib/python3.13/site-packages/pandas/core/frame.py:4378, in DataFrame.__getitem__(self, key)
#    4374
#    4375         if is_single_key:
#    4376             if self.columns.nlevels > 1:
#    4377                 return self._getitem_multilevel(key)
# -> 4378             indexer = self.columns.get_loc(key)
#    4379             if is_integer(indexer):
#    4380                 indexer = [indexer]
#    4381         else:
#
# File ~/INtREC/ML project/.venv/lib/python3.13/site-packages/pandas/core/indexes/base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 'marks'

# %%
df["Marks"]
# Out:
# 0     70
# 1     80
# 2     90
# 3    100
# Name: Marks, dtype: int64

# %%
df[df["Marks"]>80]
# Out:
#        Name  Age  Marks
# 2  Tharindu   29     90
# 3   Savindi   31    100

# %%
df["Marks"].mean()
# Out:
# np.float64(85.0)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of        Name  Age  Marks
# 0    Anjula   25     70
# 1    Anjali   25     80
# 2  Tharindu   29     90
# 3   Savindi   31    100>

# %%
df.describe()
# Out:
#         Age       Marks
# count   4.0    4.000000
# mean   27.5   85.000000
# std     3.0   12.909944
# min    25.0   70.000000
# 25%    25.0   77.500000
# 50%    27.0   85.000000
# 75%    29.5   92.500000
# max    31.0  100.000000

# %%
df.isnull().sum()
# Out:
# Name     0
# Age      0
# Marks    0
# dtype: int64
