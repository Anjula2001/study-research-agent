# %%
Hello World
# Out:
#   Cell In[1], line 1
#     Hello World
#           ^
# SyntaxError: invalid syntax

# %%
print ("Hello world")
# Out:
# Hello world

# %%
name = "Anjula"
age = 25

print (name)
print(age)
# Out:
# Anjula
# 25

# %%
import numpy as np

numbers = np.array([10, 20, 30, 40, 50])

print(numbers)
print(numbers.mean())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import numpy as np
#       2
#       3 numbers = np.array([10, 20, 30, 40, 50])
#       4
#
# ModuleNotFoundError: No module named 'numpy'

# %%
import numpy as np

numbers = np.array([10, 20, 30, 40, 50])

print(numbers)
print(numbers.mean())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import numpy as np
#       2
#       3 numbers = np.array([10, 20, 30, 40, 50])
#       4
#
# ModuleNotFoundError: No module named 'numpy'

# %%
import numpy as np

numbers = np.array([10, 20, 30, 40, 50])

print(numbers)
print(numbers.mean())
# Out:
# [10 20 30 40 50]
# 30.0

# %%
import numpy as np

numbers = np.array([10, 20, 30, 40, 50])

print(numbers)
print("Mean is : " ,numbers.mean())
# Out:
# [10 20 30 40 50]
# Mean is :  30.0

# %%
import pandas as pd

# %%
data = {
# Out:
#   Cell In[8], line 1
#     data = {
#             ^
# _IncompleteInputError: incomplete input

# %%
data = {
    "Name" ["Anjula","Anjali","Tharindu","Savindi"],
    "Age" [25,25,29,31],
    "Marks" [70,80,90,100]
}
# Out:
# <>:2: SyntaxWarning: str indices must be integers or slices, not tuple; perhaps you missed a comma?
# <>:3: SyntaxWarning: str indices must be integers or slices, not tuple; perhaps you missed a comma?
# <>:4: SyntaxWarning: str indices must be integers or slices, not tuple; perhaps you missed a comma?
# /var/folders/rd/nk8dl3y111d2tg7vjm9phvmw0000gn/T/ipykernel_69627/3857932786.py:2: SyntaxWarning: str indices must be integers or slices, not tuple; perhaps you missed a comma?
#   "Name" ["Anjula","Anjali","Tharindu","Savindi"],
# /var/folders/rd/nk8dl3y111d2tg7vjm9phvmw0000gn/T/ipykernel_69627/3857932786.py:3: SyntaxWarning: str indices must be integers or slices, not tuple; perhaps you missed a comma?
#   "Age" [25,25,29,31],
# /var/folders/rd/nk8dl3y111d2tg7vjm9phvmw0000gn/T/ipykernel_69627/3857932786.py:4: SyntaxWarning: str indices must be integers or slices, not tuple; perhaps you missed a comma?
#   "Marks" [70,80,90,100]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 data = {
# ----> 2     "Name" ["Anjula","Anjali","Tharindu","Savindi"],
#       3     "Age" [25,25,29,31],
#       4     "Marks" [70,80,90,100]
#       5 }
#
# TypeError: string indices must be integers, not 'tuple'

# %%
data = {
    "Name" ["Anjula","Anjali","Tharindu","Savindi"],
    "Age" [25,25,29,31],
    "Marks" [70,80,90,100]
}
df = pd.DataFrame(data)
print(df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 data = {
# ----> 2     "Name" ["Anjula","Anjali","Tharindu","Savindi"],
#       3     "Age" [25,25,29,31],
#       4     "Marks" [70,80,90,100]
#       5 }
#
# TypeError: string indices must be integers, not 'tuple'

# %%
import pandas as pd
data = {
    "Name" ["Anjula","Anjali","Tharindu","Savindi"],
    "Age" [25,25,29,31],
    "Marks" [70,80,90,100]
}
df = pd.DataFrame(data)
print(df)
# Out:
# <>:5: SyntaxWarning: str indices must be integers or slices, not tuple; perhaps you missed a comma?
# /var/folders/rd/nk8dl3y111d2tg7vjm9phvmw0000gn/T/ipykernel_69627/731765383.py:5: SyntaxWarning: str indices must be integers or slices, not tuple; perhaps you missed a comma?
#   "Marks" [70,80,90,100]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 3
#       1 import pandas as pd
#       2 data = {
# ----> 3     "Name" ["Anjula","Anjali","Tharindu","Savindi"],
#       4     "Age" [25,25,29,31],
#       5     "Marks" [70,80,90,100]
#       6 }
#
# TypeError: string indices must be integers, not 'tuple'

# %%
data = {
    "Name" : ["Anjula","Anjali","Tharindu","Savindi"],
    "Age" : [25,25,29,31],
    "Marks" : [70,80,90,100]
}
df = pd.DataFrame(data)
print(df)
# Out:
#        Name  Age  Marks
# 0    Anjula   25     70
# 1    Anjali   25     80
# 2  Tharindu   29     90
# 3   Savindi   31    100
